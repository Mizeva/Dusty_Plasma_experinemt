# %% [markdown]
# <a href="https://colab.research.google.com/github/Mizeva/Dusty_Plasma_experinemt/blob/main/some_frames_1700.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.core.function_base import linspace
import matplotlib.pyplot as plt
import numpy as np
from statistics import mean
import math
from scipy.optimize import curve_fit
import pandas as pd
from scipy.misc import derivative
import math

# %%
ang = [[0 for i in range(5)] for j in range(4)]

# %% [markdown]
# каждый кадр

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    plt.plot(X, Y)
    l = [60, 71, 63, 63]
    e = [67, 76, 73, 70]
    #t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    a, c = curve_fit(mapping, X[l[num]:e[num]], Y[l[num]:e[num]])
    plt.plot(X[l[num]:e[num]], a[0] * X[l[num]:e[num]] + a[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    print(a[0], X[l[num]], X[e[num]])
    ang[num][0] = a[0]
    plt.grid()
    plt.show()


f_pd = pd.read_excel("/content/entropy_1700_1.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]


for i in range(4):
    log_graph(eps, par[i], i)

comp1 = [[0 for i in range(6)] for i in range(len(f))]
comp_eps1 = [[0 for i in range(6)] for i in range(len(f))]
comp1[0] = par[0]
comp_eps1[0] = eps

comp2 = [[0 for i in range(6)] for i in range(len(f))]
comp_eps2 = [[0 for i in range(6)] for i in range(len(f))]
comp2[0] = par[1]
comp_eps2[0] = eps

comp3 = [[0 for i in range(6)] for i in range(len(f))]
comp_eps3 = [[0 for i in range(6)] for i in range(len(f))]
comp3[0] = par[2]
comp_eps3[0] = eps

comp4 = [[0 for i in range(6)] for i in range(len(f))]
comp_eps4 = [[0 for i in range(6)] for i in range(len(f))]
comp4[0] = par[3]
comp_eps4[0] = eps
# Out:
# -3.427373366497833 -5.442473856167744 -4.465619574291479
# -5.6570028959794225 -3.9074171275050458 -3.209664069022002
# -3.0599830590225494 -5.023822021077918 -3.628315904111832
# -3.4068341293870805 -5.023822021077918 -4.0469677392016585

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    e = [67, 76, 73, 70]
    c = ['royalblue', 'orange', 'r', 'g']
    if (num != 3):
      plt.plot(X[:e[num]], Y[:e[num]], color = c[num])
    #t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    #a, c = curve_fit(mapping, X[l[num]:e[num]], Y[l[num]:e[num]])
    #plt.plot(X[l[num]:e[num]], a[0] * X[l[num]:e[num]] + a[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    #print(a[0], X[l[num]], X[e[num]])
    #ang[num][0] = a[0]



f_pd = pd.read_excel("/content/entropy_1700_1.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps), np.log(nu_fr), color = 'black', label = 'коэффициент трения')

for i in range(4):
    log_graph(eps, par[i], i)

plt.grid()
plt.xlabel('ln($\epsilon$)', fontsize = '12')
plt.ylabel('ln(S)', fontsize = '12')
plt.title('1700 fps, каждый кадр', fontsize = '16')
plt.legend()
plt.show()

# %% [markdown]
# каждый 2 кадр

# %%
def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    plt.plot(X, Y)
    l = [60, 72, 63, 63]
    e = [67, 76, 73, 70]
    t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    plt.plot(X[l[num]:e[num]], t[0] * X[l[num]:e[num]] + t[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    print(t[0])
    ang[num][1] = t[0]
    plt.grid()
    plt.show()


f_pd = pd.read_excel("/content/entropy_1700_2.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]


for i in range(4):
    log_graph(eps, par[i], i)

comp1[1] = par[0]
comp_eps1[1] = eps

comp2[1] = par[1]
comp_eps2[1] = eps

comp3[1] = par[2]
comp_eps3[1] = eps

comp4[1] = par[3]
comp_eps4[1] = eps
# Out:
# -3.4358331242003906
# -6.105019222737301
# -3.1000936215643216
# -3.3724050297364783

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    e = [67, 76, 73, 70]
    c = ['royalblue', 'orange', 'r', 'g']
    if num != 3:
      plt.plot(X[:e[num]], Y[:e[num]], color = c[num])
    #t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    #a, c = curve_fit(mapping, X[l[num]:e[num]], Y[l[num]:e[num]])
    #plt.plot(X[l[num]:e[num]], a[0] * X[l[num]:e[num]] + a[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    #print(a[0], X[l[num]], X[e[num]])
    #ang[num][0] = a[0]



f_pd = pd.read_excel("/content/entropy_1700_2.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps), np.log(nu_fr), color = 'black')

for i in range(4):
    log_graph(eps, par[i], i)
plt.grid()
plt.xlabel('ln($\epsilon$)', fontsize = '12')
plt.ylabel('ln(S)', fontsize = '12')
plt.title('1700 fps, каждый 2 кадр', fontsize = '16')
plt.show()

# %% [markdown]
# каждый 4 кадр

# %%
def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    plt.plot(X, Y)
    l = [60, 70, 63, 63]
    e = [67, 76, 73, 70]
    t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    plt.plot(X[l[num]:e[num]], t[0] * X[l[num]:e[num]] + t[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    print(t[0])
    ang[num][2] = t[0]
    plt.grid()
    plt.show()


f_pd = pd.read_excel("/content/entropy_1700_4.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]


for i in range(4):
    log_graph(eps, par[i], i)

comp1[2] = par[0]
comp_eps1[2] = eps

comp2[2] = par[1]
comp_eps2[2] = eps

comp3[2] = par[2]
comp_eps3[2] = eps

comp4[2] = par[3]
comp_eps4[2] = eps
# Out:
# -3.624290955164745
# -5.627959506317448
# -3.1485792465526594
# -3.3087700752775477

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    e = [67, 76, 73, 70]
    c = ['royalblue', 'orange', 'r', 'g']
    if num != 3:
      plt.plot(X[:e[num]], Y[:e[num]], color = c[num])

f_pd = pd.read_excel("/content/entropy_1700_4.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps), np.log(nu_fr), color = 'black')

for i in range(4):
    log_graph(eps, par[i], i)
plt.grid()
plt.xlabel('ln($\epsilon$)', fontsize = '12')
plt.ylabel('ln(S)', fontsize = '12')
plt.title('1700 fps, каждый 4 кадр', fontsize = '16')
plt.show()

# %% [markdown]
# каждый 8 кадр

# %%
def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    plt.plot(X, Y)
    l = [60, 70, 63, 63]
    e = [67, 76, 73, 70]
    t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    plt.plot(X[l[num]:e[num]], t[0] * X[l[num]:e[num]] + t[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    print(t[0])
    ang[num][3] = t[0]
    plt.grid()
    plt.show()


f_pd = pd.read_excel("/content/entropy_1700_8.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]


for i in range(4):
    log_graph(eps, par[i], i)

comp1[3] = par[0]
comp_eps1[3] = eps

comp2[3] = par[1]
comp_eps2[3] = eps

comp3[3] = par[2]
comp_eps3[3] = eps

comp4[3] = par[3]
comp_eps4[3] = eps
# Out:
# -3.6023454220397464
# -5.630721057022279
# -3.127940736430756
# -3.292207553556885

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    e = [67, 76, 73, 70]
    c = ['royalblue', 'orange', 'r', 'g']
    if num != 3:
      plt.plot(X[:e[num]], Y[:e[num]], color = c[num])

f_pd = pd.read_excel("/content/entropy_1700_8.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps), np.log(nu_fr), color = 'black')

for i in range(4):
    log_graph(eps, par[i], i)
plt.grid()
plt.xlabel('ln($\epsilon$)', fontsize = '12')
plt.ylabel('ln(S)', fontsize = '12')
plt.title('1700 fps, каждый 8 кадр', fontsize = '16')
plt.show()

# %% [markdown]
# каждый 100 кадр

# %%
def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    plt.plot(X, Y)
    l = [60, 70, 63, 63]
    e = [67, 76, 73, 70]
    t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    plt.plot(X[l[num]:e[num]], t[0] * X[l[num]:e[num]] + t[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    print(t[0])
    ang[num][4] = t[0]
    plt.grid()
    plt.show()


f_pd = pd.read_excel("/content/entropy_1700_100.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]


for i in range(4):
    log_graph(eps, par[i], i)

comp1[4] = par[0]
comp_eps1[4] = eps

comp2[4] = par[1]
comp_eps2[4] = eps

comp3[4] = par[2]
comp_eps3[4] = eps

comp4[4] = par[3]
comp_eps4[4] = eps
# Out:
# -2.2485595034202874
# -4.726313607680567
# -2.322905889373878
# -2.3016231330848314

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    e = [67, 76, 73, 70]
    c = ['royalblue', 'orange', 'r', 'g']
    if num != 3:
      plt.plot(X[:e[num]], Y[:e[num]], color = c[num])

f_pd = pd.read_excel("/content/entropy_1700_100.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps), np.log(nu_fr), color = 'black')

for i in range(4):
    log_graph(eps, par[i], i)
plt.grid()
plt.xlabel('ln($\epsilon$)', fontsize = '12')
plt.ylabel('ln(S)', fontsize = '12')
plt.title('1700 fps, каждый 100 кадр', fontsize = '16')
plt.show()

# %%
for i in range(4):
  print(i+1, ' частица')
  print('   каждый    ', ang[i][0], '\n   второй    ', ang[i][1], '\n   четвертый ', ang[i][2], '\n   восьмой   ', ang[i][3], '\n   сотый     ', ang[i][4])
# Out:
# 1  частица
#    каждый     -3.427373366497833
#    второй     -3.4358331242003906
#    четвертый  -3.624290955164745
#    восьмой    -3.6023454220397464
#    сотый      -2.2485595034202874
# 2  частица
#    каждый     -5.6570028959794225
#    второй     -6.105019222737301
#    четвертый  -5.627959506317448
#    восьмой    -5.630721057022279
#    сотый      -4.726313607680567
# 3  частица
#    каждый     -3.0599830590225494
#    второй     -3.1000936215643216
#    четвертый  -3.1485792465526594
#    восьмой    -3.127940736430756
#    сотый      -2.322905889373878
# 4  частица
#    каждый     -3.4068341293870805
#    второй     -3.3724050297364783
#    четвертый  -3.3087700752775477
#    восьмой    -3.292207553556885
#    сотый      -2.3016231330848314

# %%
ang_17 = [0 for i in range(4)]

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    plt.plot(X, Y)
    l = [61, 67, 63, 76]
    e = [74, 75, 72, 81]
    #t = np.polyfit(X[l[num]:e[num]], Y[l[num]:e[num]], deg=1)
    a, c = curve_fit(mapping, X[l[num]:e[num]], Y[l[num]:e[num]])
    plt.plot(X[l[num]:e[num]], a[0] * X[l[num]:e[num]] + a[1], color = "red")
    #plt.scatter(X[l[num]], Y[l[num]], color = "red")
    print(a[0])
    ang_17[num] = a[0]
    plt.grid()
    plt.show()


f_pd = pd.read_excel("/content/entropy_17fps_5900.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]


for i in range(4):
    log_graph(eps, par[i], i)

comp1[5] = par[2]
comp_eps1[5] = eps

comp2[5] = par[3]
comp_eps2[5] = eps

comp3[5] = par[0]
comp_eps3[5] = eps

comp4[5] = par[1]
comp_eps4[5] = eps
# Out:
# -3.2160192801940344
# -4.2975230472219135
# -2.953003772443066
# -5.408760848090107

# %%
def mapping(x, a, b):
  return a*x+b

def log_graph(x, y, num):
    leng = 0
    while math.isnan(y[leng]) != True:
        leng += 1
    diff(np.log(x[:leng]), np.log(y[:leng]), num)


def diff(X, Y, num):
    e = [67, 76, 73, 70]
    c = ['r', 'g', 'royalblue', 'orange']
    if num != 3:
      plt.plot(X[:e[num]], Y[:e[num]], color = c[num])

f_pd = pd.read_excel("/content/entropy_17fps_5900.xlsx")
f = np.array(f_pd)
eps = np.array([0.0 for i in range(len(f))])
par = np.array([[0.0 for i in range(len(f))] for j in range(4)])
for i in range(len(f)):
    eps[i] = f[i][0]

for j in range(0, 4):
  for i in range(len(f)):
    par[j][i] = f[i][j+1]

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps), np.log(nu_fr), color = 'black')

for i in range(4):
    log_graph(eps, par[i], i)
plt.grid()
plt.xlabel('ln($\epsilon$)', fontsize = '12')
plt.ylabel('ln(S)', fontsize = '12')
plt.title('17 fps', fontsize = '16')
plt.show()

# %%
#1я частица

plt.figure(figsize = (15, 11))
lab = ['1700fps, каждый кадр', '1700fps, каждый 2 кадр', '1700fps, каждый 4 кадр', '1700fps, каждый 8 кадр', '1700fps, каждый 100 кадр', '17fps']
for i in range(6):
  e = [67, 67, 67, 67, 67, 70]
  plt.plot(np.log(comp_eps1[i][25:e[i]]), np.log(comp1[i][25:e[i]]), label = lab[i])

nu_fr = np.array([11 for i in range(len(f))])
plt.plot(np.log(eps[25:70]), np.log(nu_fr[25:70]), color = 'black', label = 'коэффициент трения')

plt.grid()
plt.text(-10, 2.5, "коэффициент трения", fontsize = '20')
plt.legend(lab, fontsize = 'xx-large')
plt.xlabel('ln($\epsilon$)', fontsize = '25')
plt.ylabel('ln(S)', fontsize = '25')
plt.title('Коэффициент трения в сравнении с графиками \n динамической энтропии для одной частицы', fontsize = '28')
plt.tick_params(axis='both', which='major', labelsize=20)
plt.show()

# %%
#2я частица

plt.figure(figsize = (15, 11))
lab = ['1700fps, каждый кадр', '1700fps, каждый 2 кадр', '1700fps, каждый 4 кадр', '1700fps, каждый 8 кадр', '1700fps, каждый 100 кадр', '17fps']
for i in range(6):
  e = [76, 76, 76, 76, 76, 81]
  plt.plot(np.log(comp_eps2[i][25:e[i]]), np.log(comp2[i][25:e[i]]), label = lab[i])


plt.grid()
plt.legend(fontsize = 'large')
plt.xlabel('ln($\epsilon$)', fontsize = '16')
plt.ylabel('ln(S)', fontsize = '16')
plt.show()

# %%
#3я частица

plt.figure(figsize = (15, 11))
lab = ['1700fps, каждый кадр', '1700fps, каждый 2 кадр', '1700fps, каждый 4 кадр', '1700fps, каждый 8 кадр', '1700fps, каждый 100 кадр', '17fps']
for i in range(6):
  e = [73, 73, 73, 73, 73, 74]
  plt.plot(np.log(comp_eps3[i][:e[i]]), np.log(comp3[i][:e[i]]), label = lab[i])


plt.grid()
plt.legend(fontsize = 'large')
plt.xlabel('ln($\epsilon$)', fontsize = '16')
plt.ylabel('ln(S)', fontsize = '16')
plt.show()

# %%
#4я частица

plt.figure(figsize = (15, 11))
lab = ['1700fps, каждый кадр', '1700fps, каждый 2 кадр', '1700fps, каждый 4 кадр', '1700fps, каждый 8 кадр', '1700fps, каждый 100 кадр', '17fps']
for i in range(6):
  e = [70, 70, 70, 70, 70, 75]
  plt.plot(np.log(comp_eps4[i][:e[i]]), np.log(comp4[i][:e[i]]), label = lab[i])


plt.grid()
plt.legend(fontsize = 'large')
plt.xlabel('ln($\epsilon$)', fontsize = '16')
plt.ylabel('ln(S)', fontsize = '16')
plt.show()
